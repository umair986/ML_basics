# %%
import pandas as pd
import pandas as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/tips (1).csv')

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.shape
# Out:
# (244, 7)

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
df['sex'].replace(["Female", "Male"], [0,1], inplace = True)
df ['smoker'].replace(["No", "Yes"], [0,1], inplace = True)
df['day'].replace(['Sun','Mon','Tue','Wed','Thur','Fri','Sat'],[0,1,2,3,4,5,6],inplace = True)
df['time'].replace(['Lunch', 'Dinner'],[0,1,],inplace = True)

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     1     2
# 1         10.34  1.66    1       0    0     1     3
# 2         21.01  3.50    1       0    0     1     3
# 3         23.68  3.31    1       0    0     1     2
# 4         24.59  3.61    0       0    0     1     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    6     1     3
# 240       27.18  2.00    0       1    6     1     2
# 241       22.67  2.00    1       1    6     1     2
# 242       17.82  1.75    1       0    6     1     2
# 243       18.78  3.00    0       0    4     1     2
#
# [244 rows x 7 columns]

# %%
df['sex'].value_counts()
# Out:
# 1    157
# 0     87
# Name: sex, dtype: int64

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     1     2
# 1         10.34  1.66    1       0    0     1     3
# 2         21.01  3.50    1       0    0     1     3
# 3         23.68  3.31    1       0    0     1     2
# 4         24.59  3.61    0       0    0     1     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    6     1     3
# 240       27.18  2.00    0       1    6     1     2
# 241       22.67  2.00    1       1    6     1     2
# 242       17.82  1.75    1       0    6     1     2
# 243       18.78  3.00    0       0    4     1     2
#
# [244 rows x 7 columns]

# %%
# @title day vs total_bill

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['day'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='total_bill', y='day', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-23-23845862d642>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='total_bill', y='day', inner='stick', palette='Dark2')

# %%
X = df.drop(['tip'], axis ='columns')

# %%
Y = df['tip']

# %%
X
# Out:
#      total_bill  sex  smoker  day  time  size
# 0         16.99    0       0    0     1     2
# 1         10.34    1       0    0     1     3
# 2         21.01    1       0    0     1     3
# 3         23.68    1       0    0     1     2
# 4         24.59    0       0    0     1     4
# ..          ...  ...     ...  ...   ...   ...
# 239       29.03    1       0    6     1     3
# 240       27.18    0       1    6     1     2
# 241       22.67    1       1    6     1     2
# 242       17.82    1       0    6     1     2
# 243       18.78    0       0    4     1     2
#
# [244 rows x 6 columns]

# %%
Y
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.25, shuffle='True')

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import metrics
from sklearn.metrics import r2_score, confusion_matrix

# %%
reg = LinearRegression().fit(X,Y)

# %%
Y_pred = reg.predict(X_test)

# %%
Y_pred
# Out:
# array([1.97852267, 2.53050313, 2.76469782, 4.85059501, 2.31978623,
#        1.92650846, 2.5567939 , 3.50659871, 2.59452603, 3.7618876 ,
#        1.86691835, 2.55115595, 3.05468347, 2.94612357, 4.76201724,
#        2.52911067, 1.96741772, 3.95720504, 4.11842369, 3.08894772,
#        3.13258696, 3.85698044, 2.69879146, 1.85402304, 3.98126019,
#        3.18568147, 2.39606991, 2.38972143, 2.76770401, 3.05538287,
#        2.55261479, 2.49235794, 3.19378533, 4.87192018, 2.72557845,
#        2.51683728, 4.13054727, 2.80936204, 2.33700825, 3.03885983,
#        4.59401435, 3.34339885, 3.01525601, 2.93581069, 1.75840178,
#        2.52968729, 4.70971669, 4.32689055, 2.85388747, 2.9505779 ,
#        2.23667939, 1.55349822, 2.40572715, 2.82773545, 3.38248994,
#        3.80477255, 2.12986376, 2.73822009, 2.25576333, 5.09015399,
#        2.69662256])

# %%
import sklearn.metrics as metrics

# %%
from matplotlib.pyplot import rcParams
tips_new =X

# %%
corr = tips_new.corr()
rcParams['figure.figsize']=(15,7)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
Y_test
# Out:
# 169    2.00
# 22     2.23
# 115    3.50
# 184    3.00
# 139    2.75
#        ...
# 236    1.00
# 205    3.23
# 124    2.52
# 95     4.73
# 40     2.24
# Name: tip, Length: 61, dtype: float64

# %%
sns.lmplot(x='total_bill',y='tip',data = df)
